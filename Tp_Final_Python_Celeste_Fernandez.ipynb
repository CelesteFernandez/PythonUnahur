# %% [markdown]
# <a href="https://colab.research.google.com/github/CelesteFernandez/PythonUnahur/blob/main/Tp_Final_Python_Celeste_Fernandez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Para comenzar **UN SOLO COMPAÑERO** debe de **copiar este documento** y **compartir como EDITOR al otro compañero**, y agregar al **docente como EDITOR**.
#
# ![imagen.png](data:image/png;base64,...)
#
#
# ![imagen.png](data:image/png;base64,...)
#
# ![imagen.png](data:image/png;base64,...)
#
#
# ![imagen.png](data:image/png;base64,...)
#
#
# ![imagen.png](data:image/png;base64,...)
#
#
# *   Las etapas a realizar son con un orden establecido por que las funciones creadas en la etapa anterior **VAN A SER USADAS** en la siguiente etapa.
# *   Las funciones deben de estar **DOCUMENTADAS**.
# *   Las funciones creadas **DEBEN** de ser usadas.
# *   Son libres de **crear más funciones** si las creen necesarias.
#
#
#
# #**ETAPA 1**
#
# **Funciones matemáticas:**
#
# Crear las funciones:
#
# *   suma(sum1,sum2)
# *   resta(rest1,rest2)
# *   multiplicacion(mul1,mul2)
# *   division(div1,div2)
# *   divisonEntera(divE1,divE2)
# *   restoDivisionEntera(rDivE1,rDivE2)
# *   potencia(base,expo)
#
#
# Estas funciones deben recibir por **parámetro enteros** con los
# que va a operar, y debe **imprimir por pantalla** un texto que indique que **operacion
# se realizó y el valor resultante** de la operación.
#
# **Ingreso de datos:**
#
# crear una función **inputUsuario(textoAMostrar)** que reciba por **parámetro un texto**
# para acompañar el ingreso de un dato pedido por consola, que **convierta el dato
# recibido en entero, y lo retorne.**
#
# #**ETAPA 2**
#
# **Calculadora:**
#
# Crear la función **calculadora()**, que mediante la **indicación del usuario** realice
# alguna de las operaciones anteriormente creadas. La función calculadora deberá
# **tomar un dato por consola**, y en base a ese dato **acceder a la operación** o **imprimir
# por pantalla** que hubo un **error**. Una vez validado el dato, **pedirle al usuario** los
# **números a operar** y **pasarlos a la operacion correspondiente**. Cuando se **termina** de ejecutar la operación , debe de **mostrar un mensaje de cierre de programa** y terminar.
#
# Para que el usuario tenga una **mejor visualización** de las opciones crearemos la
# función **menu()** que **mostrará por pantalla** todas las **opciones a tomar** e indicando
# el número de opción a utilizar en la calculadora para acceder a la operación deseada.
#
# #**ETAPA 3**
#
# **Números primos:**
#
# Crear la función **esPrimo(num)**, que  toma por **parámetro un número entero** y **retorna un booleano** indicando **si es o no** un **número primo**.
# Un **número primo** es un número natural mayor que 1 que tiene únicamente dos **divisores** distintos: **él mismo y el 1**. EJ:(2,3,5,7,etc)
#
# Crear la función **numerosPrimosHasta(num)** toma por **parámetro un número entero** y **retorna una lista** con los **números primos desde el 2 hasta el número indicado**.
#
# Integrar la función **numerosPrimosHasta(num)** a nuestra calculadora.
#
# **Calculadora Parte 2:**
#
# Haremos que nuestra función **calculadora()** funcione **hasta que se le indique**.
# Haremos que se **repita el proceso** de pedir opción, ingreso de datos y mostrado de
# resultado hasta que lo **indique el usuario**.
#
# Para ello **agregaremos una opción más a nuestro menú** que será que al **ingresar 0
# se terminara el programa** y agregaremos una **estructura de control** a nuestra función
# **calculadora()** que **evalúe la condición** anteriormente mencionada para **continuar iterando o terminar la función**.
#
# **Historial:**
#
# Crear un **diccionario vacío** con el que iremos llevando un **historial de las operaciones
# realizadas** con nuestra calculadora. En el diccionario guardaremos como **KEY un texto
# que indica qué operación se realizó y con qué valores**, y el el **VALUE guardaremos el
# resultado de la operación**.
#
# Para **agregar estos datos al diccionario** creado, crearemos una función **agregarHistorial(key, value)** que recibe por **parámetro los datos para agregar un elemento más al diccionario**.
#
# Para **visualizar este historial**, crearemos la función **historial()** que **muestre por
# pantalla** el **historial de operaciones y resultados** hechos en esa ejecución.
#
# Integrar la función **historial()** a nuestra calculadora.

# %%
#propósito: Dados dos valores ingresados por teclado, calcula la suma y guarda en el historial
#parámetros: sum1 int
#            sum2 int 
#precondión: -
def suma(sum1,sum2):
  resultadoSuma = sum1 + sum2
  agregarHistorial(f"{contadorOperacion()}: suma: {sum1} y {sum2}.", f"rta: {resultadoSuma}")
  print("Se realizo la operación suma, el resultado es: ", resultadoSuma)


#propósito: Dados dos valores ingresados por teclado, calcula la resta y guarda en el historial
#parámetros: rest1 int
#            rest2 int 
#precondión: -
def resta(rest1,rest2):
  resultadoResta = rest1 - rest2
  agregarHistorial(f"{contadorOperacion()}: resta: {rest1} y {rest2}",f"rta: {resultadoResta}")
  print("Se realizo la operación resta, el resultado es: ", resultadoResta)


#propósito: Dados dos valores ingresados por teclado, calcula la multiplicacicón y guarda en el historial
#parámetros: mul1 int
#            mul2 int 
#precondión: -
def multiplicacion(mul1,mul2):
  resultadoMultiplicacion = mul1 * mul2
  agregarHistorial(f"{contadorOperacion()}: multiplicacion: {mul1} y {mul2}", f"rta: {resultadoMultiplicacion}")
  print("Se realizo la operación multiplicación, el resultado es: ", resultadoMultiplicacion)


#propósito: Dados dos valores ingresados por teclado, calcula la división y guarda en el historial
#parámetros: div1 int
#            div2 int 
#precondión: div 2 distinto de 0
def division(div1,div2):
  resultadoDivision = div1 / div2
  agregarHistorial(f"{contadorOperacion()}: division: {div1} y {div2}",f"rta: {resultadoDivision}")
  print("Se realizo la operación división, el resultado es: ", resultadoDivision)


#propósito: Dados dos valores ingresados por teclado, calcula la división entera y guarda en el historial
#parámetros: DivE1 int
#            DivE2 int
#precondición: DivE2 distinto de 0
def divisionEntera(divE1,divE2):
  resultadoDivEnt = divE1 // divE2
  agregarHistorial(f"{contadorOperacion()}: division entera: {divE1} y {divE2} ",f"rta {resultadoDivEnt}")
  print("Se realizó la operación división entera, el resultado es: ", resultadoDivEnt)


#propósito: Dados dos valores ingresados por teclado, calcula el resto de la división entera y guarda en el historial
#parámetros: rDivE1 int
#            rDivE2 int
#precondición: rDivE2 distinto de 0
def restoDivisionEntera(rDivE1,rDivE2):
  resultadoResto = rDivE1 % rDivE2
  agregarHistorial(f"{contadorOperacion()}: resto division entera: {rDivE1} y {rDivE2}",f"rta: {resultadoResto}")
  print("Se realizo la operación resto de división entera, el resultado es: ", resultadoResto)


#propósito: Dados dos valores ingresados por teclado, calcula la potencia y guarda en el historial
#parámetros: base int
#            expo int 
#precondión: -
def potencia(base,expo):
  resultadoPotencia = base ** expo
  agregarHistorial(f"{contadorOperacion()}: Potencia {base} elevado a {expo}",f"rta: {resultadoPotencia}")
  print("Se realizo la operación potencia, el resultado es: ", resultadoPotencia)


#propósito: Devuelve como entero el valor ingresado por teclado por el usuario. 
#           Además muestra un texto a elegir por el programador, para que el usuario entienda qué valor ingresar
#parámetros: textoAMostrar String
#precondición: - 
def inputUsuario(textoAMostrar):
  print(textoAMostrar)
  out = int(input())
  return out


#propósito: Muestra una lista de opciones para que el usuario elija por teclado cuál quiere usar y devuelve la ocpión elegida.
#parámetros: -
#precondición: - 
def menu():
  print("Elija la opción a utilizar: ")
  print(" 1: suma")
  print(" 2: resta")
  print(" 3: Multiplicaicón")
  print(" 4: división")
  print(" 5: división entera")
  print(" 6: resto de división entera ")
  print(" 7: potencia")
  print(" 8: primos hasta")
  print(" 9: ver historial")
  print(" 0: para terminar")


#propósito: Muestra mensaje de cierre de calculadora.
#parámetros: -
#precondición: - 
def cierre():
  print("Gracias por haber utilizado la calculadora")
  

#propósito: Retorna un booleano para determinar si el numero ingresado por teclado es primo o no
#parámetros: prim int
#precondición: ingreso distinto de 0 
def esPrimo(prim):
  if prim == 0:
    print("no puede calcularse para 0")
  else :
    contador = 0
    for i in range (1,prim):
      if prim % i == 0:
        contador = contador + 1
    if contador != 1:
      return False
    else:
      return True


#propósito: Muestra todos los números primos existentes hasta el ingresado incluido y guarda en el historial
#parámetros: num int
#precondición: ingreso distinto de 0 
def numerosPrimosHasta(num):
  listaPrimosHasta = []
  for i in range (2, num + 1):
    if esPrimo(i) == True:
      listaPrimosHasta.append(i)
  print("Lo primos hasta el ", num, "son: ")
  print(listaPrimosHasta)
  agregarHistorial(f"{contadorOperacion()}: Primos hasta el {num}",listaPrimosHasta)

historial = {}


#propósito: Agrega historial la nueva operación realizada
#parámetros: opHist String
#            rtaHist int
#precondición: - 
def agregarHistorial(opHist,rtaHist):                         
  historial[opHist] = rtaHist


#propósito: Muestra en pantalla el historial de operaciones realizadas
#parámetros: lista 
#precondición: - 
def historia(): 
  print(historial)  


#propósito: Contador para la cantidad de operaciones realizadas
#parámetros: -
#precondición: - 
def contadorOperacion():
  global contOp
  contOp = contOp + 1
  return contOp


#propósito: Muetra un mensaje con la operación que se eligió
#parámetros: opcion String
#precondición: - 
def mostrarEleccion(opcion):
  print("Eligió la opción: ", opcion)


#propósito: Según la opción elegida, valida el dato, la muestra y en caso de ser correcto, realiza la operación
#parámetros: -
#precondición: - 
def calculadora():
  menu()
  opcion = inputUsuario("")
  if opcion == 1:
    mostrarEleccion("suma")
    sum1 = inputUsuario("ingrese un número: ")
    sum2 = inputUsuario("ingrese otro número: ")
    suma(sum1,sum2)
    print("")
    calculadora()
  elif opcion == 2:
    mostrarEleccion("resta")
    rest1 = inputUsuario("ingrese un número: ")
    rest2 = inputUsuario("ingrese otro número: ")
    resta(rest1,rest2)
    print("")
    calculadora()
  elif opcion == 3:
    mostrarEleccion("multiplicación")
    mul1 = inputUsuario("ingrese un número: ")
    mul2 = inputUsuario("ingrese otro número: ")
    multiplicacion(mul1, mul2)
    print("")
    calculadora()
  elif opcion == 4:
    mostrarEleccion("división")
    div1 = inputUsuario("ingrese el dividendo: ")
    div2 = inputUsuario("ingrese el divisor: ")
    division(div1, div2)
    print("")
    calculadora()
  elif opcion == 5:
    mostrarEleccion("división entera")
    divE1 = inputUsuario("ingrese el primer número: ")
    divE2 = inputUsuario("ingrese el segundo número: ")
    divisionEntera(divE1,divE2)
    print("")
    calculadora()
  elif opcion == 6:
    mostrarEleccion("resto de división entera")
    rDivE1 = inputUsuario("ingrese el primero número: ")
    rDIvE2 = inputUsuario("ingrese el segundo número: ")
    restoDivisionEntera(rDivE1,rDIvE2 )
    print("")
    calculadora()
  elif opcion == 7:
    mostrarEleccion("potencia")
    base = inputUsuario("ingrese la base: ")
    expo = inputUsuario("ingrese el exponente: ")
    potencia(base, expo)
    print("")
    calculadora()
  elif opcion == 8:
    mostrarEleccion("primos hasta")
    num = inputUsuario("ingrese un número: ")
    numerosPrimosHasta(num)
    print("")
    calculadora()
  elif opcion == 9:
    mostrarEleccion("historial")
    historia() 
    calculadora()                             
  elif opcion == 0:
    cierre()
  else:
    print("")
    print("Ingresó una opción inválida")
    print("")
    calculadora()



print("¡Bienvenido a la calculadora!")
print(" ")
contOp = 0
calculadora()
# Out:
# ¡Bienvenido a la calculadora!
#
# Elija la opción a utilizar:
#  1: suma
#  2: resta
#  3: Multiplicaicón
#  4: división
#  5: división entera
#  6: resto de división entera
#  7: potencia
#  8: primos hasta
#  9: ver historial
#  0: para terminar
#
# 1
# Eligió la opción:  suma
# ingrese un número:
# 5
# ingrese otro número:
# 2
# Se realizo la operación suma, el resultado es:  7
#
# Elija la opción a utilizar:
#  1: suma
#  2: resta
#  3: Multiplicaicón
#  4: división
#  5: división entera
#  6: resto de división entera
#  7: potencia
#  8: primos hasta
#  9: ver historial
#  0: para terminar
#
# 1
# Eligió la opción:  suma
# ingrese un número:
# 5
# ingrese otro número:
# 2
# Se realizo la operación suma, el resultado es:  7
#
# Elija la opción a utilizar:
#  1: suma
#  2: resta
#  3: Multiplicaicón
#  4: división
#  5: división entera
#  6: resto de división entera
#  7: potencia
#  8: primos hasta
#  9: ver historial
#  0: para terminar
#
# 8
# Eligió la opción:  primos hasta
# ...
